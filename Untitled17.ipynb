# %%
import pandas as pd

# %%
df=pd.read_csv("D:/AgentPerformance.csv")
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df.describe()
# Out:
#              SL No  Total Chats  Average Rating  Total Feedback
# count  2160.000000  2160.000000     2160.000000     2160.000000
# mean   1080.500000     6.814815        1.460963        4.286574
# std     623.682612    11.705233        2.074763        7.412594
# min       1.000000     0.000000        0.000000        0.000000
# 25%     540.750000     0.000000        0.000000        0.000000
# 50%    1080.500000     0.000000        0.000000        0.000000
# 75%    1620.250000    13.000000        4.120000        7.000000
# max    2160.000000    97.000000        5.000000       56.000000

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Date', 'Agent Name', 'Average Response Time',
#        'Average Resolution Time', 'category1'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes=="object"].index]
# Out:
#             Date          Agent Name Average Response Time  \
# 0      7/30/2022        Prerna Singh              00:00:38
# 1      7/30/2022       Nandani Gupta              00:01:15
# 2      7/30/2022          Ameya Jain              00:00:30
# 3      7/30/2022       Mahesh Sarade              00:01:04
# 4      7/30/2022              Swati               00:01:11
# ...          ...                 ...                   ...
# 2155  07-01-2022   Sowmiya Sivakumar              00:00:00
# 2156  07-01-2022             Nitin M              00:00:00
# 2157  07-01-2022              Vivek               00:00:00
# 2158  07-01-2022       Ayushi Mishra              00:00:00
# 2159  07-01-2022  Chaitra K Hiremath              00:00:00
#
#      Average Resolution Time
# 0                   00:04:20
# 1                   00:28:25
# 2                   00:11:36
# 3                   00:15:46
# 4                   00:16:33
# ...                      ...
# 2155                00:00:00
# ...

# %%
df['Total Chats'][1:4]
# Out:
# 1    11
# 2    14
# 3    14
# Name: Total Chats, dtype: int64

# %%
df['category1']="Kunal"

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.columns
# Out:
# Index(['SL No', 'Date', 'Agent Name', 'Total Chats', 'Average Response Time',
#        'Average Resolution Time', 'Average Rating', 'Total Feedback',
#        'category1'],
#       dtype='object')

# %%
df[df['Average Rating']==max(df['Average Rating'])]['Agent Name']
# Out:
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
# 68      Shivananda Sonwane
# 75             Muskan Garg
# 85      Chaitra K Hiremath
#                ...
# 2016           Madhulika G
# 2022              Bharath
# 2086        Jawala Prakash
# 2098              Shivan K
# 2100        Shubham Sharma
# Name: Agent Name, Length: 71, dtype: object

# %%
date=pd.to_datetime(df['Date'])

# %%
date
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
df['date1']=pd.to_datetime(df['Date'])
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df['year']=df['date1'].dt.year

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df['Total Chats'].value_counts()
# Out:
# 0     1415
# 20      33
# 23      32
# 18      31
# 15      29
#       ...
# 97       1
# 67       1
# 51       1
# 49       1
# 50       1
# Name: Total Chats, Length: 61, dtype: int64

# %%
df.drop('Total Chats',axis=1)
# Out:
#       SL No        Date          Agent Name Average Response Time  \
# 0         1   7/30/2022        Prerna Singh              00:00:38
# 1         2   7/30/2022       Nandani Gupta              00:01:15
# 2         3   7/30/2022          Ameya Jain              00:00:30
# 3         4   7/30/2022       Mahesh Sarade              00:01:04
# 4         5   7/30/2022              Swati               00:01:11
# ...     ...         ...                 ...                   ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar              00:00:00
# 2156   2157  07-01-2022             Nitin M              00:00:00
# 2157   2158  07-01-2022              Vivek               00:00:00
# 2158   2159  07-01-2022       Ayushi Mishra              00:00:00
# 2159   2160  07-01-2022  Chaitra K Hiremath              00:00:00
#
#      Average Resolution Time  Average Rating  Total Feedback category1  \
# 0                   00:04:20            4.11               9     Kunal
# ...

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.drop(1)
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# 5         6   7/30/2022             Mukesh             9
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# ...

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.loc[[2,3]]
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 2      3  7/30/2022     Ameya Jain           14              00:00:30
# 3      4  7/30/2022  Mahesh Sarade           14              00:01:04
#
#   Average Resolution Time  Average Rating  Total Feedback category1  \
# 2                00:11:36            4.55              11     Kunal
# 3                00:15:46            4.71               7     Kunal
#
#        date1  year
# 2 2022-07-30  2022
# 3 2022-07-30  2022

# %%
df.loc[2:10]
# Out:
#     SL No       Date       Agent Name  Total Chats Average Response Time  \
# 2       3  7/30/2022       Ameya Jain           14              00:00:30
# 3       4  7/30/2022    Mahesh Sarade           14              00:01:04
# 4       5  7/30/2022           Swati            14              00:01:11
# 5       6  7/30/2022          Mukesh             9              00:00:34
# 6       7  7/30/2022  Saikumarreddy N           15              00:00:31
# 7       8  7/30/2022    Sanjeev Kumar           12              00:00:55
# 8       9  7/30/2022   Shubham Sharma           13              00:01:31
# 9      10  7/30/2022     Nishtha Jain           20              00:00:59
# 10     11  7/30/2022     Manjunatha A           11              00:00:47
#
#    Average Resolution Time  Average Rating  Total Feedback category1  \
# 2                 00:11:36            4.55              11     Kunal
# 3                 00:15:46            4.71               7     Kunal
# ...

# %%
df.loc[0:4,['Date','Agent Name', 'Total Chats']]
# Out:
#         Date     Agent Name  Total Chats
# 0  7/30/2022   Prerna Singh           11
# 1  7/30/2022  Nandani Gupta           11
# 2  7/30/2022     Ameya Jain           14
# 3  7/30/2022  Mahesh Sarade           14
# 4  7/30/2022         Swati            14

# %%
df.iloc[0:4,0:3]
# Out:
#    SL No       Date     Agent Name
# 0      1  7/30/2022   Prerna Singh
# 1      2  7/30/2022  Nandani Gupta
# 2      3  7/30/2022     Ameya Jain
# 3      4  7/30/2022  Mahesh Sarade

# %%
df[df.dtypes[(df.dtypes=='int64') | (df.dtypes=='float64')]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12228/2883019894.py in <module>
# ----> 1 df[df.dtypes[(df.dtypes=='int64') | (df.dtypes=='float64')]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df.dtypes
# Out:
# SL No                               int64
# Date                               object
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# category1                          object
# date1                      datetime64[ns]
# year                                int64
# dtype: object

# %%
df2=df[df.dtypes[(df.dtypes=='int64') | (df.dtypes=='float64')].index]

# %%
df2
# Out:
#       SL No  Total Chats  Average Rating  Total Feedback  year
# 0         1           11            4.11               9  2022
# 1         2           11            3.14               7  2022
# 2         3           14            4.55              11  2022
# 3         4           14            4.71               7  2022
# 4         5           14            3.67               6  2022
# ...     ...          ...             ...             ...   ...
# 2155   2156            0            0.00               0  2022
# 2156   2157            0            0.00               0  2022
# 2157   2158            0            0.00               0  2022
# 2158   2159            0            0.00               0  2022
# 2159   2160            0            0.00               0  2022
#
# [2160 rows x 5 columns]

# %%
df3=df2[df2>10]

# %%
df3
# Out:
#        SL No  Total Chats  Average Rating  Total Feedback  year
# 0        NaN         11.0             NaN             NaN  2022
# 1        NaN         11.0             NaN             NaN  2022
# 2        NaN         14.0             NaN            11.0  2022
# 3        NaN         14.0             NaN             NaN  2022
# 4        NaN         14.0             NaN             NaN  2022
# ...      ...          ...             ...             ...   ...
# 2155  2156.0          NaN             NaN             NaN  2022
# 2156  2157.0          NaN             NaN             NaN  2022
# 2157  2158.0          NaN             NaN             NaN  2022
# 2158  2159.0          NaN             NaN             NaN  2022
# 2159  2160.0          NaN             NaN             NaN  2022
#
# [2160 rows x 5 columns]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [SL No, Total Chats, Average Rating, Total Feedback, year]
# Index: []

# %%
df3.dropna(axis=1)
# Out:
#       year
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 2155  2022
# 2156  2022
# 2157  2022
# 2158  2022
# 2159  2022
#
# [2160 rows x 1 columns]

# %%
df3.dropna(thresh=3)
# Out:
#        SL No  Total Chats  Average Rating  Total Feedback  year
# 2        NaN         14.0             NaN            11.0  2022
# 6        NaN         15.0             NaN            12.0  2022
# 9        NaN         20.0             NaN            16.0  2022
# 10      11.0         11.0             NaN             NaN  2022
# 11      12.0         20.0             NaN            14.0  2022
# ...      ...          ...             ...             ...   ...
# 2101  2102.0         25.0             NaN            13.0  2022
# 2102  2103.0         23.0             NaN            14.0  2022
# 2103  2104.0         24.0             NaN            18.0  2022
# 2104  2105.0         15.0             NaN             NaN  2022
# 2105  2106.0         22.0             NaN             NaN  2022
#
# [574 rows x 5 columns]

# %%
df3.fillna(4)
# Out:
#        SL No  Total Chats  Average Rating  Total Feedback  year
# 0        4.0         11.0             4.0             4.0  2022
# 1        4.0         11.0             4.0             4.0  2022
# 2        4.0         14.0             4.0            11.0  2022
# 3        4.0         14.0             4.0             4.0  2022
# 4        4.0         14.0             4.0             4.0  2022
# ...      ...          ...             ...             ...   ...
# 2155  2156.0          4.0             4.0             4.0  2022
# 2156  2157.0          4.0             4.0             4.0  2022
# 2157  2158.0          4.0             4.0             4.0  2022
# 2158  2159.0          4.0             4.0             4.0  2022
# 2159  2160.0          4.0             4.0             4.0  2022
#
# [2160 rows x 5 columns]

# %%
df3.fillna(value=df3['Total Chats'].mean())
# Out:
#            SL No  Total Chats  Average Rating  Total Feedback  year
# 0       23.87931     11.00000        23.87931        23.87931  2022
# 1       23.87931     11.00000        23.87931        23.87931  2022
# 2       23.87931     14.00000        23.87931        11.00000  2022
# 3       23.87931     14.00000        23.87931        23.87931  2022
# 4       23.87931     14.00000        23.87931        23.87931  2022
# ...          ...          ...             ...             ...   ...
# 2155  2156.00000     23.87931        23.87931        23.87931  2022
# 2156  2157.00000     23.87931        23.87931        23.87931  2022
# 2157  2158.00000     23.87931        23.87931        23.87931  2022
# 2158  2159.00000     23.87931        23.87931        23.87931  2022
# 2159  2160.00000     23.87931        23.87931        23.87931  2022
#
# [2160 rows x 5 columns]

# %%
df
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1   7/30/2022        Prerna Singh           11
# 1         2   7/30/2022       Nandani Gupta           11
# 2         3   7/30/2022          Ameya Jain           14
# 3         4   7/30/2022       Mahesh Sarade           14
# 4         5   7/30/2022              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  07-01-2022   Sowmiya Sivakumar            0
# 2156   2157  07-01-2022             Nitin M            0
# 2157   2158  07-01-2022              Vivek             0
# 2158   2159  07-01-2022       Ayushi Mishra            0
# 2159   2160  07-01-2022  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# ...

# %%
df.groupby('Date')['Total Feedback'].mean()
# Out:
# Date
# 07-01-2022    2.513889
# 07-02-2022    3.486111
# 07-03-2022    2.958333
# 07-04-2022    2.777778
# 07-05-2022    2.708333
# 07-06-2022    2.708333
# 07-07-2022    4.333333
# 07-08-2022    2.958333
# 07-09-2022    3.027778
# 07-10-2022    3.208333
# 07-11-2022    4.013889
# 07-12-2022    4.527778
# 7/13/2022     3.708333
# 7/14/2022     4.055556
# 7/15/2022     4.291667
# 7/16/2022     5.652778
# 7/17/2022     4.819444
# 7/18/2022     5.791667
# 7/19/2022     6.208333
# 7/20/2022     5.638889
# 7/21/2022     4.930556
# 7/22/2022     4.777778
# 7/23/2022     5.861111
# 7/24/2022     4.694444
# 7/25/2022     6.291667
# 7/26/2022     5.027778
# 7/27/2022     4.986111
# 7/28/2022     5.250000
# 7/29/2022     4.305556
# 7/30/2022     3.083333
# Name: Total Feedback, dtype: float64

# %%
df.groupby('Date')['Total Feedback'].sum()
# Out:
# Date
# 07-01-2022    181
# 07-02-2022    251
# 07-03-2022    213
# 07-04-2022    200
# 07-05-2022    195
# 07-06-2022    195
# 07-07-2022    312
# 07-08-2022    213
# 07-09-2022    218
# 07-10-2022    231
# 07-11-2022    289
# 07-12-2022    326
# 7/13/2022     267
# 7/14/2022     292
# 7/15/2022     309
# 7/16/2022     407
# 7/17/2022     347
# 7/18/2022     417
# 7/19/2022     447
# 7/20/2022     406
# 7/21/2022     355
# 7/22/2022     344
# 7/23/2022     422
# 7/24/2022     338
# 7/25/2022     453
# 7/26/2022     362
# 7/27/2022     359
# 7/28/2022     378
# 7/29/2022     310
# 7/30/2022     222
# Name: Total Feedback, dtype: int64

# %%
data = {'name' : ['sudh' , 'krish' , 'hitesh' , 'tulesko'],
        'salary' : [100 , 200 , 300 , 400],
        'mail_id' : ['sudh@ineuron.ai' , 'krish@ineuron.ai' , 'hitesh@ineuron.ai' , 'tulesko@ineuron.ai'],
        'addr' : ['blr' , 'blr' , 'blr' , 'mum']
    }

# %%
new_df=pd.DataFrame(data,index=['4','5','6','7'])

# %%
new_df
# Out:
#       name  salary             mail_id addr
# 4     sudh     100     sudh@ineuron.ai  blr
# 5    krish     200    krish@ineuron.ai  blr
# 6   hitesh     300   hitesh@ineuron.ai  blr
# 7  tulesko     400  tulesko@ineuron.ai  mum

# %%
new_df.iloc[0:4]
# Out:
#       name  salary             mail_id addr
# 4     sudh     100     sudh@ineuron.ai  blr
# 5    krish     200    krish@ineuron.ai  blr
# 6   hitesh     300   hitesh@ineuron.ai  blr
# 7  tulesko     400  tulesko@ineuron.ai  mum

# %%
data1= {'pf_nu' : [234,45,54465,656],
        'income_tax' : [234,565,767,6778],
        'mobile_no' : [23543,43543,454,5656],
        'courses' : ['ds' , 'bigdata' , 'web dev ' , 'blockchian']
    
}

# %%
new_df1=pd.DataFrame(data1)
new_df1
# Out:
#    pf_nu  income_tax  mobile_no     courses
# 0    234         234      23543          ds
# 1     45         565      43543     bigdata
# 2  54465         767        454    web dev
# 3    656        6778       5656  blockchian

# %%
new_df=pd.DataFrame(data)
new_df
# Out:
#       name  salary             mail_id addr
# 0     sudh     100     sudh@ineuron.ai  blr
# 1    krish     200    krish@ineuron.ai  blr
# 2   hitesh     300   hitesh@ineuron.ai  blr
# 3  tulesko     400  tulesko@ineuron.ai  mum

# %%
pd.concat([new_df,new_df1],axis=1)
# Out:
#       name  salary             mail_id addr  pf_nu  income_tax  mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         234      23543
# 1    krish     200    krish@ineuron.ai  blr     45         565      43543
# 2   hitesh     300   hitesh@ineuron.ai  blr  54465         767        454
# 3  tulesko     400  tulesko@ineuron.ai  mum    656        6778       5656
#
#       courses
# 0          ds
# 1     bigdata
# 2    web dev
# 3  blockchian

# %%
pd.concat([new_df,new_df1])
# Out:
#       name  salary             mail_id addr    pf_nu  income_tax  mobile_no  \
# 0     sudh   100.0     sudh@ineuron.ai  blr      NaN         NaN        NaN
# 1    krish   200.0    krish@ineuron.ai  blr      NaN         NaN        NaN
# 2   hitesh   300.0   hitesh@ineuron.ai  blr      NaN         NaN        NaN
# 3  tulesko   400.0  tulesko@ineuron.ai  mum      NaN         NaN        NaN
# 0      NaN     NaN                 NaN  NaN    234.0       234.0    23543.0
# 1      NaN     NaN                 NaN  NaN     45.0       565.0    43543.0
# 2      NaN     NaN                 NaN  NaN  54465.0       767.0      454.0
# 3      NaN     NaN                 NaN  NaN    656.0      6778.0     5656.0
#
#       courses
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 0          ds
# 1     bigdata
# 2    web dev
# 3  blockchian

# %%
data2 = {'0' : ['sudh' , 'krish' , 'hitesh' , 'tulesko'],
        '1' : [100 , 200 , 300 , 400],
        '2' : ['sudh@ineuron.ai' , 'krish@ineuron.ai' , 'hitesh@ineuron.ai' , 'tulesko@ineuron.ai'],
        '3' : ['blr' , 'blr' , 'blr' , 'mum']
    }

# %%
data3= {'0' : [234,45,54465,656],
        '1' : [234,565,767,6778],
        '2' : [23543,43543,454,5656],
        '3' : ['ds' , 'bigdata' , 'web dev ' , 'blockchian']
    
}

# %%
new_df2=pd.DataFrame(data2)
new_df2
# Out:
#          0    1                   2    3
# 0     sudh  100     sudh@ineuron.ai  blr
# 1    krish  200    krish@ineuron.ai  blr
# 2   hitesh  300   hitesh@ineuron.ai  blr
# 3  tulesko  400  tulesko@ineuron.ai  mum

# %%
new_df3=pd.DataFrame(data3)
new_df3
# Out:
#        0     1      2           3
# 0    234   234  23543          ds
# 1     45   565  43543     bigdata
# 2  54465   767    454    web dev
# 3    656  6778   5656  blockchian

# %%
data4 = {'emp_id' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }

# %%
data5  = {'emp_id' : [101,102,104,105],
          'mob_no' : [3434,5656,767,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
new_df4=pd.DataFrame(data4)
new_df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102     345  34
# 2     103     200  56
# 3     104     400  78

# %%
new_df5=pd.DataFrame(data5)
new_df5
# Out:
#    emp_id  mob_no  house_nu
# 0     101    3434       345
# 1     102    5656       345
# 2     104     767       345
# 3     105     878        56

# %%
pd.merge(new_df4,new_df5,how='left')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23  3434.0     345.0
# 1     102     345  34  5656.0     345.0
# 2     103     200  56     NaN       NaN
# 3     104     400  78   767.0     345.0

# %%
pd.merge(new_df4,new_df5,how='left',on='emp_id')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23  3434.0     345.0
# 1     102     345  34  5656.0     345.0
# 2     103     200  56     NaN       NaN
# 3     104     400  78   767.0     345.0

# %%
data6 = {'emp_id1' : [101,102,103,104],
         'salary' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data7  = {'emp_id2' : [101,102,104,105],
          'mob_no' : [3434,5656,767,878],
          'house_nu' : [345,345,345,56]
    
}

# %%
new_df6=pd.DataFrame(data6)

# %%
new_df7=pd.DataFrame(data7)

# %%
new_df6
# Out:
#    emp_id1  salary  pf
# 0      101     234  23
# 1      102     345  34
# 2      103     200  56
# 3      104     400  78

# %%
new_df7
# Out:
#    emp_id2  mob_no  house_nu
# 0      101    3434       345
# 1      102    5656       345
# 2      104     767       345
# 3      105     878        56

# %%
pd.merge(new_df6,new_df7,left_on='emp_id1',right_on='emp_id2',how='inner')
# Out:
#    emp_id1  salary  pf  emp_id2  mob_no  house_nu
# 0      101     234  23      101    3434       345
# 1      102     345  34      102    5656       345
# 2      104     400  78      104     767       345

# %%
data10 = {'emp_id1' : [101,102,103,104],
         'salary1' : [234, 345,200,400],
         'pf' : [23,34,56,78],
         }
         
data11  = {'emp_id2' : [101,102,104,105,123],
          'salary2' : [234, 345,200,878,43],
          'house_nu' : [345,345,345,56,234]
    
}

# %%
new_df10=pd.DataFrame(data10)
new_df10
# Out:
#    emp_id1  salary1  pf
# 0      101      234  23
# 1      102      345  34
# 2      103      200  56
# 3      104      400  78

# %%
new_df11=pd.DataFrame(data11)
new_df11
# Out:
#    emp_id2  salary2  house_nu
# 0      101      234       345
# 1      102      345       345
# 2      104      200       345
# 3      105      878        56
# 4      123       43       234

# %%
new_df10.join(new_df11)
# Out:
#    emp_id1  salary1  pf  emp_id2  salary2  house_nu
# 0      101      234  23      101      234       345
# 1      102      345  34      102      345       345
# 2      103      200  56      104      200       345
# 3      104      400  78      105      878        56
